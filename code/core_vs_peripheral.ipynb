# %%
import geopandas as gpd
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Destiny's To Do:
#
# - [x] Reclassify core/peripheral stations using data-driven approach
# - [x] Investigate Downtown Berkeley Census Data
# - [x] Visualizations
# - [x] Missing data (report)
# - [] Clean up code (put notebook code into python file)

# %% [markdown]
# ## New Transit Data

# %%
transit = pd.read_csv('../data/transit_gdf.csv')
transit
# Out:
#     Unnamed: 0   station_id                                  name   latitude  \
# 0            0         12TH          12th St. Oakland City Center  37.803768
# 1            1         16TH                      16th St. Mission  37.765062
# 2            2         19TH                      19th St. Oakland  37.808350
# 3            3         24TH                      24th St. Mission  37.752470
# 4            4         ANTC                               Antioch  37.995388
# ..         ...          ...                                   ...        ...
# 76          76  santa_clara          Santa Clara Caltrain Station  37.353384
# 77          77     south_sf  South San Francisco Caltrain Station  37.655941
# 78          78     stanford                              Stanford  37.438950
# 79          79    sunnyvale                             Sunnyvale  37.378934
# 80          80       tamien               Tamien Caltrain Station  37.312690
#
#      longitude                  address           city        county  zipcode  \
# 0  -122.271450            1245 Broadway        Oakland       alameda  94612.0
# 1  -122.419694      2000 Mission Street  San Francisco  sanfrancisco  94110.0
# 2  -122.268602            1900 Broadway        Oakland       alameda  94612.0
# 3  -122.418143      2800 Mission Street  San Francisco  sanfrancisco  94110.0
# 4  -121.780420  1600 Slatten Ranch Road        Antioch  Contra Costa  94509.0
# ..         ...                      ...            ...           ...      ...
# 76 -121.936465                      NaN            NaN           NaN      NaN
# 77 -122.404979                      NaN            NaN           NaN      NaN
# 78 -122.157150                      NaN            NaN           NaN      NaN
# 79 -122.031500                      NaN            NaN           NaN      NaN
# 80 -121.884700                      NaN            NaN           NaN      NaN
#
#       agency           mode                             geometry
# 0       BART     Heavy Rail         POINT (-122.27145 37.803768)
# 1       BART     Heavy Rail        POINT (-122.419694 37.765062)
# 2       BART     Heavy Rail         POINT (-122.268602 37.80835)
# 3       BART     Heavy Rail         POINT (-122.418143 37.75247)
# 4       BART     Heavy Rail         POINT (-121.78042 37.995388)
# ..       ...            ...                                  ...
# 76  Caltrain  Commuter Rail        POINT (-121.936465 37.353384)
# 77  Caltrain  Commuter Rail  POINT (-122.404979006 37.655941416)
# 78  Caltrain  Commuter Rail          POINT (-122.15715 37.43895)
# 79  Caltrain  Commuter Rail          POINT (-122.0315 37.378934)
# 80  Caltrain  Commuter Rail           POINT (-121.8847 37.31269)
#
# [81 rows x 12 columns]

# %%
transit['name'].values
# Out:
# <StringArray>
# [        '12th St. Oakland City Center',
#                      '16th St. Mission',
#                      '19th St. Oakland',
#                      '24th St. Mission',
#                               'Antioch',
#                                 'Ashby',
#                           'Balboa Park',
#                              'Bay Fair',
#              'Berryessa/North San Jose',
#                         'Castro Valley',
#                 'Civic Center/UN Plaza',
#                              'Coliseum',
#                                 'Colma',
#                               'Concord',
#                             'Daly City',
#                     'Downtown Berkeley',
#                     'Dublin/Pleasanton',
#                  'El Cerrito del Norte',
#                      'El Cerrito Plaza',
#                           'Embarcadero',
#                               'Fremont',
#                             'Fruitvale',
#                             'Glen Park',
#                               'Hayward',
#                             'Lafayette',
#                          'Lake Merritt',
#                             'MacArthur',
#                              'Millbrae',
#                              'Milpitas',
#                        'Montgomery St.',
#                        'North Berkeley',
#                'North Concord/Martinez',
#         'Oakland International Airport',
#                                'Orinda',
#                   'Pittsburg/Bay Point',
#                      'Pittsburg Center',
#     'Pleasant Hill/Contra Costa Centre',
#                            'Powell St.',
#                              'Richmond',
#                             'Rockridge',
#                             'San Bruno',
#   'San Francisco International Airport',
#                           'San Leandro',
#                         'South Hayward',
#                   'South San Francisco',
#                            'Union City',
#                          'Walnut Creek',
#            'Warm Springs/South Fremont',
#                'West Dublin/Pleasanton',
#                          'West Oakland',
#                           '22nd Street',
#                              'Bayshore',
#                               'Belmont',
#         'Blossom Hill Caltrain Station',
#                              'Broadway',
#                            'Burlingame',
#                     'California Avenue',
#              'Capitol Caltrain Station',
#                          'College Park',
#                                'Gilroy',
#                          'Hayward Park',
#                             'Hillsdale',
#                              'Lawrence',
#                            'Menlo Park',
#                              'Millbrae',
#                           'Morgan Hill',
#                         'Mountain View',
#                             'Palo Alto',
#                          'Redwood City',
#                           'San Antonio',
#            'San Bruno Caltrain Station',
#                            'San Carlos',
#        'San Francisco Caltrain Station',
#                      'San Jose Diridon',
#                            'San Martin',
#                             'San Mateo',
#          'Santa Clara Caltrain Station',
#  'South San Francisco Caltrain Station',
#                              'Stanford',
#                             'Sunnyvale',
#               'Tamien Caltrain Station']
# Length: 81, dtype: str

# %%
duplicated_station = transit['name'].duplicated()
transit.loc[duplicated_station, 'name'] = 'Millbrae Caltrain Station'

# %%
classification = pd.read_csv('../output/classification_results_fy2025.csv')
classification = classification.rename(columns = {'consensus' : "station_type"})
classification
# Out:
#               station    agency                       metric  \
# 0         Embarcadero      BART            avg_weekday_exits
# 1   Montgomery Street      BART            avg_weekday_exits
# 2       Powell Street      BART            avg_weekday_exits
# 3        Civic Center      BART            avg_weekday_exits
# 4       San Francisco  Caltrain  avg_mid_week_ridership_AMWR
# ..                ...       ...                          ...
# 75           Broadway  Caltrain  avg_mid_week_ridership_AMWR
# 76       Blossom Hill  Caltrain  avg_mid_week_ridership_AMWR
# 77            Capitol  Caltrain  avg_mid_week_ridership_AMWR
# 78       College Park  Caltrain  avg_mid_week_ridership_AMWR
# 79         San Martin  Caltrain  avg_mid_week_ridership_AMWR
#
#     avg_weekday_exits  rank method_percentile method_kmeans method_jenks  \
# 0               17741     1              core          core         core
# 1               14342     2              core          core         core
# 2               11002     3              core          core         core
# 3                9172     4              core          core         core
# 4                6874     5              core          core         core
# ..                ...   ...               ...           ...          ...
# 75                 91    76        peripheral    peripheral   peripheral
# 76                 71    77        peripheral    peripheral   peripheral
# 77                 49    78        peripheral    peripheral   peripheral
# 78                 41    79        peripheral    peripheral   peripheral
# 79                 25    80        peripheral    peripheral   peripheral
#
#     core_votes station_type
# 0            3         core
# 1            3         core
# 2            3         core
# 3            3         core
# 4            3         core
# ..         ...          ...
# 75           0   peripheral
# 76           0   peripheral
# 77           0   peripheral
# 78           0   peripheral
# 79           0   peripheral
#
# [80 rows x 10 columns]

# %%
classification['station_id'] = classification['station'] + '_' + classification['agency']
classification['station_id'].sort_values().values
# Out:
# <StringArray>
# [  '12th Street / Oakland City Center_BART',
#                  '16th Street Mission_BART',
#                  '19th Street Oakland_BART',
#                      '22nd Street_Caltrain',
#                  '24th Street Mission_BART',
#                              'Antioch_BART',
#                                'Ashby_BART',
#                          'Balboa Park_BART',
#                              'Bayfair_BART',
#                         'Bayshore_Caltrain',
#                          'Belmont_Caltrain',
#                             'Berkeley_BART',
#           'Berryessa / North San Jos_BART',
#                     'Blossom Hill_Caltrain',
#                         'Broadway_Caltrain',
#                       'Burlingame_Caltrain',
#                   'California Ave_Caltrain',
#                          'Capitol_Caltrain',
#                        'Castro Valley_BART',
#                         'Civic Center_BART',
#                             'Coliseum_BART',
#                     'College Park_Caltrain',
#                                'Colma_BART',
#                              'Concord_BART',
#                            'Daly City_BART',
#                    'Dublin/Pleasanton_BART',
#                 'El Cerrito Del Norte_BART',
#                     'El Cerrito Plaza_BART',
#                          'Embarcadero_BART',
#                              'Fremont_BART',
#                            'Fruitvale_BART',
#                           'Gilroy_Caltrain',
#                            'Glen Park_BART',
#                     'Hayward Park_Caltrain',
#                              'Hayward_BART',
#                        'Hillsdale_Caltrain',
#                            'Lafayette_BART',
#                         'Lake Merritt_BART',
#                         'Lawrence_Caltrain',
#                            'MacArthur_BART',
#                       'Menlo Park_Caltrain',
#                             'Millbrae_BART',
#                         'Millbrae_Caltrain',
#                             'Milpitas_BART',
#                    'Montgomery Street_BART',
#                      'Morgan Hill_Caltrain',
#                    'Mountain View_Caltrain',
#                       'North Berkeley_BART',
#                        'North Concord_BART',
#        'Oakland International Airport_BART',
#                               'Orinda_BART',
#                        'Palo Alto_Caltrain',
#                     'Pittsburg Center_BART',
#                  'Pittsburg/Bay Point_BART',
#                        'Pleasant Hill_BART',
#                        'Powell Street_BART',
#                     'Redwood City_Caltrain',
#                             'Richmond_BART',
#                            'Rockridge_BART',
#                      'San Antonio_Caltrain',
#                            'San Bruno_BART',
#                        'San Bruno_Caltrain',
#                       'San Carlos_Caltrain',
#  'San Francisco International Airport_BART',
#                    'San Francisco_Caltrain',
#                 'San Jose Diridon_Caltrain',
#                          'San Leandro_BART',
#                       'San Martin_Caltrain',
#                        'San Mateo_Caltrain',
#                      'Santa Clara_Caltrain',
#                        'South Hayward_BART',
#                  'South San Francisco_BART',
#              'South San Francisco_Caltrain',
#                        'Sunnyvale_Caltrain',
#                           'Tamien_Caltrain',
#                           'Union City_BART',
#                         'Walnut Creek_BART',
#                         'Warm Springs_BART',
#               'West Dublin/Pleasanton_BART',
#                         'West Oakland_BART']
# Length: 80, dtype: str

# %%
list(set(transit['name'].values) ^ set(classification['station'].values))
# Out:
# ['Santa Clara Caltrain Station',
#  'Berryessa/North San Jose',
#  'Pleasant Hill/Contra Costa Centre',
#  '19th St. Oakland',
#  'Montgomery St.',
#  '12th Street / Oakland City Center',
#  'California Ave',
#  'Civic Center/UN Plaza',
#  '24th Street Mission',
#  'Warm Springs/South Fremont',
#  'Civic Center',
#  '16th Street Mission',
#  'Capitol Caltrain Station',
#  'Berryessa / North San Jos\x8e',
#  'San Bruno Caltrain Station',
#  '12th St. Oakland City Center',
#  '19th Street Oakland',
#  'San Francisco',
#  'Bay Fair',
#  'San Francisco Caltrain Station',
#  'Tamien Caltrain Station',
#  'South San Francisco Caltrain Station',
#  'Bayfair',
#  'Warm Springs',
#  'Pleasant Hill',
#  'Santa Clara',
#  'Capitol',
#  'North Concord',
#  'Blossom Hill',
#  'El Cerrito Del Norte',
#  'Berkeley',
#  'Stanford',
#  '16th St. Mission',
#  'North Concord/Martinez',
#  'Powell St.',
#  'Downtown Berkeley',
#  'El Cerrito del Norte',
#  'Powell Street',
#  'Millbrae Caltrain Station',
#  '24th St. Mission',
#  'Tamien',
#  'Montgomery Street',
#  'Blossom Hill Caltrain Station',
#  'California Avenue']

# %%
classification['station_id'] = classification['station_id'].replace({
               '12th Street / Oakland City Center_BART' : "12th St. Oakland City Center",
                 '16th Street Mission_BART' : "16th St. Mission",
                 '19th Street Oakland_BART' : "19th St. Oakland",
                     '22nd Street_Caltrain' : "22nd Street",
                 '24th Street Mission_BART' : "24th St. Mission",
                             'Antioch_BART' : "Antioch",
                               'Ashby_BART' : "Ashby",
                         'Balboa Park_BART' : "Balboa Park",
                             'Bayfair_BART' : "Bay Fair",
                        'Bayshore_Caltrain' : "Bayshore",
                         'Belmont_Caltrain' : "Belmont",
                            'Berkeley_BART' : "Downtown Berkeley",
          'Berryessa / North San Jos_BART' : "Berryessa/North San Jose",
                    'Blossom Hill_Caltrain' : "Blossom Hill Caltrain Station",
                        'Broadway_Caltrain' : "Broadway",
                      'Burlingame_Caltrain' : "Burlingame",
                  'California Ave_Caltrain' : "California Avenue",
                         'Capitol_Caltrain' : "Capitol Caltrain Station",
                       'Castro Valley_BART' : "Castro Valley",
                        'Civic Center_BART' : "Civic Center/UN Plaza",
                            'Coliseum_BART' : "Coliseum",
                    'College Park_Caltrain' : "College Park",
                               'Colma_BART' : "Colma",
                             'Concord_BART' : "Concord",
                           'Daly City_BART' : "Daly City",
                   'Dublin/Pleasanton_BART' : "Dublin/Pleasanton",
                'El Cerrito Del Norte_BART' : "El Cerrito del Norte",
                    'El Cerrito Plaza_BART' : "El Cerrito Plaza",
                         'Embarcadero_BART' : "Embarcadero",
                             'Fremont_BART' : "Fremont",
                           'Fruitvale_BART' : "Fruitvale",
                          'Gilroy_Caltrain' : "Gilroy",
                           'Glen Park_BART' : "Glen Park",
                    'Hayward Park_Caltrain' : "Hayward Park",
                             'Hayward_BART' : "Hayward",
                       'Hillsdale_Caltrain' : "Hillsdale",
                           'Lafayette_BART' : "Lafayette",
                        'Lake Merritt_BART' : "Lake Merritt",
                        'Lawrence_Caltrain' : "Lawrence",
                           'MacArthur_BART' : "MacArthur",
                      'Menlo Park_Caltrain' : "Menlo Park",
                            'Millbrae_BART' : "Millbrae",
                        'Millbrae_Caltrain' : "Millbrae Caltrain Station",
                            'Milpitas_BART' : "Milpitas",
                   'Montgomery Street_BART' : "Montgomery St.",
                     'Morgan Hill_Caltrain' : "Morgan Hill",
                   'Mountain View_Caltrain' : "Mountain View",
                      'North Berkeley_BART' : "North Berkeley",
                       'North Concord_BART' : "North Concord/Martinez",
       'Oakland International Airport_BART' : "Oakland International Airport",
                              'Orinda_BART' : "Orinda",
                       'Palo Alto_Caltrain' : "Palo Alto",
                    'Pittsburg Center_BART' : "Pittsburg Center",
                 'Pittsburg/Bay Point_BART' : "Pittsburg/Bay Point",
                       'Pleasant Hill_BART' : "Pleasant Hill/Contra Costa Centre",
                       'Powell Street_BART' : "Powell St.",
                    'Redwood City_Caltrain' : "Redwood City",
                            'Richmond_BART' : "Richmond",
                           'Rockridge_BART' : "Rockridge",
                     'San Antonio_Caltrain' : "San Antonio",
                           'San Bruno_BART' : "San Bruno",
                       'San Bruno_Caltrain' : "San Bruno Caltrain Station",
                      'San Carlos_Caltrain' : "San Carlos",
 'San Francisco International Airport_BART' : "San Francisco International Airport",
                   'San Francisco_Caltrain' : "San Francisco Caltrain Station",
                'San Jose Diridon_Caltrain' : "San Jose Diridon",
                         'San Leandro_BART' : "San Leandro",
                      'San Martin_Caltrain' : "San Martin",
                       'San Mateo_Caltrain' : "San Mateo",
                     'Santa Clara_Caltrain' : "Santa Clara Caltrain Station",
                       'South Hayward_BART' : "South Hayward",
                 'South San Francisco_BART' : "South San Francisco",
             'South San Francisco_Caltrain' : "South San Francisco Caltrain Station",
                       'Sunnyvale_Caltrain' : "Sunnyvale",
                          'Tamien_Caltrain' : "Tamien Caltrain Station",
                          'Union City_BART' : "Union City",
                        'Walnut Creek_BART' : "Walnut Creek",
                        'Warm Springs_BART' : "Warm Springs/South Fremont",
              'West Dublin/Pleasanton_BART' : "West Dublin/Pleasanton",
                        'West Oakland_BART' : "West Oakland"
})

# %%
list(set(transit['name'].values) ^ set(classification['station_id'].values))
# Out:
# ['Stanford']

# %%
df = pd.merge(transit, classification[['station_id', 'station_type']], how = "inner", left_on = 'name', 
         right_on='station_id')
df
# Out:
#     Unnamed: 0 station_id_x                                  name   latitude  \
# 0            0         12TH          12th St. Oakland City Center  37.803768
# 1            1         16TH                      16th St. Mission  37.765062
# 2            2         19TH                      19th St. Oakland  37.808350
# 3            3         24TH                      24th St. Mission  37.752470
# 4            4         ANTC                               Antioch  37.995388
# ..         ...          ...                                   ...        ...
# 75          75    san_mateo                             San Mateo  37.568240
# 76          76  santa_clara          Santa Clara Caltrain Station  37.353384
# 77          77     south_sf  South San Francisco Caltrain Station  37.655941
# 78          79    sunnyvale                             Sunnyvale  37.378934
# 79          80       tamien               Tamien Caltrain Station  37.312690
#
#      longitude                  address           city        county  zipcode  \
# 0  -122.271450            1245 Broadway        Oakland       alameda  94612.0
# 1  -122.419694      2000 Mission Street  San Francisco  sanfrancisco  94110.0
# 2  -122.268602            1900 Broadway        Oakland       alameda  94612.0
# 3  -122.418143      2800 Mission Street  San Francisco  sanfrancisco  94110.0
# 4  -121.780420  1600 Slatten Ranch Road        Antioch  Contra Costa  94509.0
# ..         ...                      ...            ...           ...      ...
# 75 -122.323900                      NaN            NaN           NaN      NaN
# 76 -121.936465                      NaN            NaN           NaN      NaN
# 77 -122.404979                      NaN            NaN           NaN      NaN
# 78 -122.031500                      NaN            NaN           NaN      NaN
# 79 -121.884700                      NaN            NaN           NaN      NaN
#
#       agency           mode                             geometry  \
# 0       BART     Heavy Rail         POINT (-122.27145 37.803768)
# 1       BART     Heavy Rail        POINT (-122.419694 37.765062)
# 2       BART     Heavy Rail         POINT (-122.268602 37.80835)
# 3       BART     Heavy Rail         POINT (-122.418143 37.75247)
# 4       BART     Heavy Rail         POINT (-121.78042 37.995388)
# ..       ...            ...                                  ...
# 75  Caltrain  Commuter Rail           POINT (-122.3239 37.56824)
# 76  Caltrain  Commuter Rail        POINT (-121.936465 37.353384)
# 77  Caltrain  Commuter Rail  POINT (-122.404979006 37.655941416)
# 78  Caltrain  Commuter Rail          POINT (-122.0315 37.378934)
# 79  Caltrain  Commuter Rail           POINT (-121.8847 37.31269)
#
#                             station_id_y station_type
# 0           12th St. Oakland City Center         core
# 1                       16th St. Mission         core
# 2                       19th St. Oakland         core
# 3                       24th St. Mission         core
# 4                                Antioch   peripheral
# ..                                   ...          ...
# 75                             San Mateo   peripheral
# 76          Santa Clara Caltrain Station   peripheral
# 77  South San Francisco Caltrain Station   peripheral
# 78                             Sunnyvale   peripheral
# 79               Tamien Caltrain Station   peripheral
#
# [80 rows x 14 columns]

# %%
df.to_csv("../data/new_stations_transit_data.csv")

# %% [markdown]
# What is the difference between census_tract_data_2024.csv and census_tract_data_2024_clean.csv
# - No difference ...clean made in py file, while other made in notebook. (delete notebook)

# %%
pd.set_option('display.max_columns', None)

# %%
census_data = pd.read_csv('../data/census_tract_data_2024.csv')
census_data.iloc[143:149, :]
# Out:
#                                                  NAME  total_pop  median_age  \
# 143     Census Tract 4233; Alameda County; California       3623        41.6
# 144     Census Tract 4234; Alameda County; California       5218        35.0
# 145     Census Tract 4235; Alameda County; California       3768        33.3
# 146  Census Tract 4236.01; Alameda County; California       2603        40.7
# 147  Census Tract 4236.02; Alameda County; California       5621        24.1
# 148     Census Tract 4237; Alameda County; California       3381        26.3
#
#      total_pop_race  white_alone  black_alone  aian_alone  asian_alone  \
# 143            3623         1764          712           4          300
# 144            5218         2392         1019           0          551
# 145            3768         2198          336           0          389
# 146            2603         1630           70          26          403
# 147            5621         2892          204           0         1607
# 148            3381         2068          137           0          661
#
#      nhpi_alone  other_race_alone  two_or_more_races  median_household_income  \
# 143           0               308                535                 101571.0
# 144           0               705                551                 145789.0
# 145          10               217                618                 103702.0
# 146           2               237                235                 166310.0
# 147           0               296                622                  53952.0
# 148           2               133                380                  95833.0
#
#      per_capita_income  total_pop_poverty_calc  pop_below_poverty  \
# 143            62484.0                    3623                617
# 144            74470.0                    5218                927
# 145            66770.0                    3637                403
# 146            90543.0                    2568                326
# 147            39294.0                    5497               2295
# 148            72496.0                    2846                653
#
#      total_housing_units  total_occupied_units  owner_occupied  \
# 143                 1730                  1476             829
# 144                 2352                  1974             965
# 145                 1694                  1587             488
# 146                 1247                  1136             555
# 147                 2709                  2255             664
# 148                 1420                  1152             500
#
#      renter_occupied  total_households  owner_occ_no_vehicle  \
# 143              647              1476                    61
# 144             1009              1974                    60
# 145             1099              1587                    52
# 146              581              1136                    11
# 147             1591              2255                    77
# 148              652              1152                    38
#
#      renter_occ_no_vehicle  median_gross_rent  median_home_value  \
# 143                    192             2137.0          1101900.0
# 144                    271             2311.0          1362400.0
# 145                    294             2075.0          1162700.0
# 146                     70             2222.0          1421900.0
# 147                    831             2021.0           909500.0
# 148                    296             2132.0          2000001.0
#
#      total_workers_16plus  drove_alone  public_transit_commuters  \
# 143                  1923          638                       184
# 144                  2906         1151                       456
# 145                  2097          619                       250
# 146                  1394          397                       178
# 147                  2584          596                       394
# 148                  1595          495                       245
#
#      bicycle_commuters  walked_commuters  worked_from_home  \
# 143                215                90               687
# 144                292               101               895
# 145                197               159               574
# 146                 72               177               545
# 147                 24               639               853
# 148                 21               270               503
#
#      aggregate_travel_time_mins  labor_force  employed  unemployed  \
# 143                         NaN         2048      1954          94
# 144                     58440.0         3093      2923         170
# 145                     42810.0         2178      2106          72
# 146                         NaN         1541      1424         117
# 147                         NaN         2826      2584         242
# 148                     34190.0         1765      1665         100
#
#      pop_25plus  bachelors_degree  masters_degree  professional_degree  \
# 143        2758               752             456                  194
# 144        3980              1068            1000                  270
# 145        2755               960             638                  154
# 146        2046               611             532                   99
# 147        2662               743             560                  106
# 148        1755               483             350                  182
#
#      doctorate_degree  foreign_born  total_pop_nativity  state  county  \
# 143                99           599                3623      6       1
# 144               236           921                5218      6       1
# 145               207           578                3768      6       1
# 146               316           506                2603      6       1
# 147               266          1261                5621      6       1
# 148               400           557                3381      6       1
#
#       tract       GEOID county_name  households_no_vehicle  pct_no_vehicle  \
# 143  423300  6001423300     Alameda                    253           17.14
# 144  423400  6001423400     Alameda                    331           16.77
# 145  423500  6001423500     Alameda                    346           21.80
# 146  423601  6001423601     Alameda                     81            7.13
# 147  423602  6001423602     Alameda                    908           40.27
# 148  423700  6001423700     Alameda                    334           28.99
#
#      pop_nonwhite  pct_nonwhite  pct_white  pct_black  pct_asian  \
# 143          1859         51.31      48.69      19.65       8.28
# 144          2826         54.16      45.84      19.53      10.56
# 145          1570         41.67      58.33       8.92      10.32
# 146           973         37.38      62.62       2.69      15.48
# 147          2729         48.55      51.45       3.63      28.59
# 148          1313         38.83      61.17       4.05      19.55
#
#      poverty_rate  pct_renter  pct_owner  pct_transit_commute  \
# 143         17.03       43.83      56.17                 9.57
# 144         17.77       51.11      48.89                15.69
# 145         11.08       69.25      30.75                11.92
# 146         12.69       51.14      48.86                12.77
# 147         41.75       70.55      29.45                15.25
# 148         22.94       56.60      43.40                15.36
#
#      pct_drove_alone  pct_bike_commute  pct_walk_commute  pct_wfh  \
# 143            33.18             11.18              4.68    35.73
# 144            39.61             10.05              3.48    30.80
# 145            29.52              9.39              7.58    27.37
# 146            28.48              5.16             12.70    39.10
# 147            23.07              0.93             24.73    33.01
# 148            31.03              1.32             16.93    31.54
#
#      mean_travel_time_mins  unemployment_rate  pop_bachelors_plus  \
# 143                    NaN               4.59                1501
# 144                  20.11               5.50                2574
# 145                  20.41               3.31                1959
# 146                    NaN               7.59                1558
# 147                    NaN               8.56                1675
# 148                  21.44               5.67                1415
#
#      pct_bachelors_plus  pct_foreign_born
# 143               54.42             16.53
# 144               64.67             17.65
# 145               71.11             15.34
# 146               76.15             19.44
# 147               62.92             22.43
# 148               80.63             16.47

# %%
census_data["GEOID"] = census_data["GEOID"].astype(str).str.zfill(11)

# %%
census_data.groupby("county_name")['median_household_income'].mean()
# Out:
# county_name
# Alameda          137273.250667
# Contra Costa     138893.041667
# Marin            155614.311475
# Napa             118494.487179
# San Francisco    146049.675214
# San Mateo        168773.598837
# Santa Clara      167168.051471
# Solano           103235.367347
# Sonoma           110257.165289
# Name: median_household_income, dtype: float64

# %%
import censusgeocode as cg

rows = []

for station, (lat, lon) in zip(df['name'], zip(df['latitude'], df['longitude'])):
    result = cg.coordinates(x = lon, y = lat)
    tract = result["Census Tracts"][0]
    rows.append({
            "station": station,
            "geoid":   tract["GEOID"],
            "state":   tract["STATE"],
            "county":  tract["COUNTY"],
            "tract":   tract["TRACT"],
            "tract_name": tract["NAME"],
        })
geo_info = pd.DataFrame(rows)
geo_info
# Out:
#                                  station        geoid state county   tract  \
# 0           12th St. Oakland City Center  06001403000    06    001  403000
# 1                       16th St. Mission  06075020102    06    075  020102
# 2                       19th St. Oakland  06001402900    06    001  402900
# 3                       24th St. Mission  06075020900    06    075  020900
# 4                                Antioch  06013308002    06    013  308002
# ..                                   ...          ...   ...    ...     ...
# 75                             San Mateo  06081606202    06    081  606202
# 76          Santa Clara Caltrain Station  06085505203    06    085  505203
# 77  South San Francisco Caltrain Station  06081602300    06    081  602300
# 78                             Sunnyvale  06085508707    06    085  508707
# 79               Tamien Caltrain Station  06085503113    06    085  503113
#
#               tract_name
# 0      Census Tract 4030
# 1    Census Tract 201.02
# 2      Census Tract 4029
# 3       Census Tract 209
# 4   Census Tract 3080.02
# ..                   ...
# 75  Census Tract 6062.02
# 76  Census Tract 5052.03
# 77     Census Tract 6023
# 78  Census Tract 5087.07
# 79  Census Tract 5031.13
#
# [80 rows x 6 columns]

# %%
geo_info.to_csv("../data/geo_info_transit.csv")

# %%
merge1 = geo_info.merge(df, how = 'inner', left_on = 'station', right_on = 'name')
merge1
# Out:
#                                  station        geoid state county_x   tract  \
# 0           12th St. Oakland City Center  06001403000    06      001  403000
# 1                       16th St. Mission  06075020102    06      075  020102
# 2                       19th St. Oakland  06001402900    06      001  402900
# 3                       24th St. Mission  06075020900    06      075  020900
# 4                                Antioch  06013308002    06      013  308002
# ..                                   ...          ...   ...      ...     ...
# 75                             San Mateo  06081606202    06      081  606202
# 76          Santa Clara Caltrain Station  06085505203    06      085  505203
# 77  South San Francisco Caltrain Station  06081602300    06      081  602300
# 78                             Sunnyvale  06085508707    06      085  508707
# 79               Tamien Caltrain Station  06085503113    06      085  503113
#
#               tract_name  Unnamed: 0 station_id_x  \
# 0      Census Tract 4030           0         12TH
# 1    Census Tract 201.02           1         16TH
# 2      Census Tract 4029           2         19TH
# 3       Census Tract 209           3         24TH
# 4   Census Tract 3080.02           4         ANTC
# ..                   ...         ...          ...
# 75  Census Tract 6062.02          75    san_mateo
# 76  Census Tract 5052.03          76  santa_clara
# 77     Census Tract 6023          77     south_sf
# 78  Census Tract 5087.07          79    sunnyvale
# 79  Census Tract 5031.13          80       tamien
#
#                                     name   latitude   longitude  \
# 0           12th St. Oakland City Center  37.803768 -122.271450
# 1                       16th St. Mission  37.765062 -122.419694
# 2                       19th St. Oakland  37.808350 -122.268602
# 3                       24th St. Mission  37.752470 -122.418143
# 4                                Antioch  37.995388 -121.780420
# ..                                   ...        ...         ...
# 75                             San Mateo  37.568240 -122.323900
# 76          Santa Clara Caltrain Station  37.353384 -121.936465
# 77  South San Francisco Caltrain Station  37.655941 -122.404979
# 78                             Sunnyvale  37.378934 -122.031500
# 79               Tamien Caltrain Station  37.312690 -121.884700
#
#                     address           city      county_y  zipcode    agency  \
# 0             1245 Broadway        Oakland       alameda  94612.0      BART
# 1       2000 Mission Street  San Francisco  sanfrancisco  94110.0      BART
# 2             1900 Broadway        Oakland       alameda  94612.0      BART
# 3       2800 Mission Street  San Francisco  sanfrancisco  94110.0      BART
# 4   1600 Slatten Ranch Road        Antioch  Contra Costa  94509.0      BART
# ..                      ...            ...           ...      ...       ...
# 75                      NaN            NaN           NaN      NaN  Caltrain
# 76                      NaN            NaN           NaN      NaN  Caltrain
# 77                      NaN            NaN           NaN      NaN  Caltrain
# 78                      NaN            NaN           NaN      NaN  Caltrain
# 79                      NaN            NaN           NaN      NaN  Caltrain
#
#              mode                             geometry  \
# 0      Heavy Rail         POINT (-122.27145 37.803768)
# 1      Heavy Rail        POINT (-122.419694 37.765062)
# 2      Heavy Rail         POINT (-122.268602 37.80835)
# 3      Heavy Rail         POINT (-122.418143 37.75247)
# 4      Heavy Rail         POINT (-121.78042 37.995388)
# ..            ...                                  ...
# 75  Commuter Rail           POINT (-122.3239 37.56824)
# 76  Commuter Rail        POINT (-121.936465 37.353384)
# 77  Commuter Rail  POINT (-122.404979006 37.655941416)
# 78  Commuter Rail          POINT (-122.0315 37.378934)
# 79  Commuter Rail           POINT (-121.8847 37.31269)
#
#                             station_id_y station_type
# 0           12th St. Oakland City Center         core
# 1                       16th St. Mission         core
# 2                       19th St. Oakland         core
# 3                       24th St. Mission         core
# 4                                Antioch   peripheral
# ..                                   ...          ...
# 75                             San Mateo   peripheral
# 76          Santa Clara Caltrain Station   peripheral
# 77  South San Francisco Caltrain Station   peripheral
# 78                             Sunnyvale   peripheral
# 79               Tamien Caltrain Station   peripheral
#
# [80 rows x 20 columns]

# %%
census_data["GEOID"]
# Out:
# 0       06001400100
# 1       06001400200
# 2       06001400300
# 3       06001400400
# 4       06001400500
#            ...
# 1767    06097154305
# 1768    06097154306
# 1769    06097154307
# 1770    06097154308
# 1771    06097990100
# Name: GEOID, Length: 1772, dtype: str

# %%
transit_census_df = merge1.merge(census_data, left_on = 'geoid', right_on = 'GEOID')
transit_census_df
# Out:
#                                  station        geoid state_x county_x  \
# 0           12th St. Oakland City Center  06001403000      06      001
# 1                       16th St. Mission  06075020102      06      075
# 2                       19th St. Oakland  06001402900      06      001
# 3                       24th St. Mission  06075020900      06      075
# 4                                Antioch  06013308002      06      013
# ..                                   ...          ...     ...      ...
# 75                             San Mateo  06081606202      06      081
# 76          Santa Clara Caltrain Station  06085505203      06      085
# 77  South San Francisco Caltrain Station  06081602300      06      081
# 78                             Sunnyvale  06085508707      06      085
# 79               Tamien Caltrain Station  06085503113      06      085
#
#    tract_x            tract_name  Unnamed: 0 station_id_x  \
# 0   403000     Census Tract 4030           0         12TH
# 1   020102   Census Tract 201.02           1         16TH
# 2   402900     Census Tract 4029           2         19TH
# 3   020900      Census Tract 209           3         24TH
# 4   308002  Census Tract 3080.02           4         ANTC
# ..     ...                   ...         ...          ...
# 75  606202  Census Tract 6062.02          75    san_mateo
# 76  505203  Census Tract 5052.03          76  santa_clara
# 77  602300     Census Tract 6023          77     south_sf
# 78  508707  Census Tract 5087.07          79    sunnyvale
# 79  503113  Census Tract 5031.13          80       tamien
#
#                                     name   latitude   longitude  \
# 0           12th St. Oakland City Center  37.803768 -122.271450
# 1                       16th St. Mission  37.765062 -122.419694
# 2                       19th St. Oakland  37.808350 -122.268602
# 3                       24th St. Mission  37.752470 -122.418143
# 4                                Antioch  37.995388 -121.780420
# ..                                   ...        ...         ...
# 75                             San Mateo  37.568240 -122.323900
# 76          Santa Clara Caltrain Station  37.353384 -121.936465
# 77  South San Francisco Caltrain Station  37.655941 -122.404979
# 78                             Sunnyvale  37.378934 -122.031500
# 79               Tamien Caltrain Station  37.312690 -121.884700
#
#                     address           city      county_y  zipcode    agency  \
# 0             1245 Broadway        Oakland       alameda  94612.0      BART
# 1       2000 Mission Street  San Francisco  sanfrancisco  94110.0      BART
# 2             1900 Broadway        Oakland       alameda  94612.0      BART
# 3       2800 Mission Street  San Francisco  sanfrancisco  94110.0      BART
# 4   1600 Slatten Ranch Road        Antioch  Contra Costa  94509.0      BART
# ..                      ...            ...           ...      ...       ...
# 75                      NaN            NaN           NaN      NaN  Caltrain
# 76                      NaN            NaN           NaN      NaN  Caltrain
# 77                      NaN            NaN           NaN      NaN  Caltrain
# 78                      NaN            NaN           NaN      NaN  Caltrain
# 79                      NaN            NaN           NaN      NaN  Caltrain
#
#              mode                             geometry  \
# 0      Heavy Rail         POINT (-122.27145 37.803768)
# 1      Heavy Rail        POINT (-122.419694 37.765062)
# 2      Heavy Rail         POINT (-122.268602 37.80835)
# 3      Heavy Rail         POINT (-122.418143 37.75247)
# 4      Heavy Rail         POINT (-121.78042 37.995388)
# ..            ...                                  ...
# 75  Commuter Rail           POINT (-122.3239 37.56824)
# 76  Commuter Rail        POINT (-121.936465 37.353384)
# 77  Commuter Rail  POINT (-122.404979006 37.655941416)
# 78  Commuter Rail          POINT (-122.0315 37.378934)
# 79  Commuter Rail           POINT (-121.8847 37.31269)
#
#                             station_id_y station_type  \
# 0           12th St. Oakland City Center         core
# 1                       16th St. Mission         core
# 2                       19th St. Oakland         core
# 3                       24th St. Mission         core
# 4                                Antioch   peripheral
# ..                                   ...          ...
# 75                             San Mateo   peripheral
# 76          Santa Clara Caltrain Station   peripheral
# 77  South San Francisco Caltrain Station   peripheral
# 78                             Sunnyvale   peripheral
# 79               Tamien Caltrain Station   peripheral
#
#                                                  NAME  total_pop  median_age  \
# 0       Census Tract 4030; Alameda County; California       3387        40.4
# 1   Census Tract 201.02; San Francisco County; Cal...       3463        45.0
# 2       Census Tract 4029; Alameda County; California       2431        37.2
# 3   Census Tract 209; San Francisco County; Califo...       3746        38.4
# 4   Census Tract 3080.02; Contra Costa County; Cal...       5146        39.9
# ..                                                ...        ...         ...
# 75  Census Tract 6062.02; San Mateo County; Califo...       3428        33.1
# 76  Census Tract 5052.03; Santa Clara County; Cali...       5725        22.5
# 77    Census Tract 6023; San Mateo County; California       4245        37.9
# 78  Census Tract 5087.07; Santa Clara County; Cali...       3907        33.1
# 79  Census Tract 5031.13; Santa Clara County; Cali...       4028        35.9
#
#     total_pop_race  white_alone  black_alone  aian_alone  asian_alone  \
# 0             3387          444          320           2         2178
# 1             3463          981          272          57          623
# 2             2431          661          603          10          692
# 3             3746         1222           38          33          612
# 4             5146         1196         1254         155          620
# ..             ...          ...          ...         ...          ...
# 75            3428          632           14           0          901
# 76            5725         2794          250          23         1700
# 77            4245          775           84           0         1280
# 78            3907          825           37          43         2172
# 79            4028          864           48          53          351
#
#     nhpi_alone  other_race_alone  two_or_more_races  median_household_income  \
# 0           48                48                347                  58794.0
# 1            0              1009                521                 100761.0
# 2            0               112                353                  66050.0
# 3            0              1170                671                  96250.0
# 4           22               935                964                 119896.0
# ..         ...               ...                ...                      ...
# 75          15               957                909                 138250.0
# 76          35               213                710                 139028.0
# 77         157               759               1190                 146750.0
# 78           0               341                489                 173165.0
# 79           0              1963                749                  95625.0
#
#     per_capita_income  total_pop_poverty_calc  pop_below_poverty  \
# 0             60439.0                    3387                799
# 1             55597.0                    3463                948
# 2             89947.0                    2417                515
# 3             67562.0                    3733                387
# 4             50923.0                    5134                452
# ..                ...                     ...                ...
# 75            77701.0                    3399                120
# 76            54862.0                    3500                974
# 77            66247.0                    4240                525
# 78           103876.0                    3907                273
# 79            44893.0                    4028                186
#
#     total_housing_units  total_occupied_units  owner_occupied  \
# 0                  2413                  2034             353
# 1                  1861                  1306             221
# 2                  2071                  1715              12
# 3                  1898                  1607             223
# 4                  1669                  1648            1375
# ..                  ...                   ...             ...
# 75                 1262                  1209             475
# 76                 1593                  1519             800
# 77                 1553                  1409             803
# 78                 1698                  1573             653
# 79                 1337                  1308             486
#
#     renter_occupied  total_households  owner_occ_no_vehicle  \
# 0              1681              2034                   182
# 1              1085              1306                    60
# 2              1703              1715                     0
# 3              1384              1607                    50
# 4               273              1648                    12
# ..              ...               ...                   ...
# 75              734              1209                    15
# 76              719              1519                    38
# 77              606              1409                    52
# 78              920              1573                    21
# 79              822              1308                    21
#
#     renter_occ_no_vehicle  median_gross_rent  median_home_value  \
# 0                    1008             2128.0           573000.0
# 1                     639             1764.0          1098000.0
# 2                    1029             2096.0                NaN
# 3                     480             2446.0          1296100.0
# 4                      15             2585.0           726400.0
# ..                    ...                ...                ...
# 75                    116             3062.0          1092900.0
# 76                    103             3266.0          1198700.0
# 77                     44             3054.0          1144800.0
# 78                    122             2639.0          1530200.0
# 79                    150             2048.0          1065000.0
#
#     total_workers_16plus  drove_alone  public_transit_commuters  \
# 0                   1659          331                       440
# 1                   1668          432                       315
# 2                   1496          298                       484
# 3                   2157          438                       715
# 4                   2477         1615                        94
# ..                   ...          ...                       ...
# 75                  1935         1018                        80
# 76                  2920         1046                       225
# 77                  2618         1637                       110
# 78                  2524         1036                       105
# 79                  2237         1361                        43
#
#     bicycle_commuters  walked_commuters  worked_from_home  \
# 0                   0               137               707
# 1                  87               248               467
# 2                  19                86               446
# 3                 114               101               730
# 4                   0                 1               328
# ..                ...               ...               ...
# 75                 26                48               373
# 76                 49               626               781
# 77                 28                17               459
# 78                108                47               908
# 79                 61                 0               295
#
#     aggregate_travel_time_mins  labor_force  employed  unemployed  pop_25plus  \
# 0                          NaN         1931      1760         171        3024
# 1                          NaN         2150      1684         466        2885
# 2                          NaN         1648      1525         123        2182
# 3                      43075.0         2478      2279         199        2979
# 4                     112050.0         2752      2527         225        3583
# ..                         ...          ...       ...         ...         ...
# 75                     52240.0         2043      1982          61        2472
# 76                     49895.0         3275      3084         191        2480
# 77                     55550.0         2778      2699          79        2971
# 78                     40040.0         2747      2562         185        3080
# 79                     59800.0         2343      2274          69        3017
#
#     bachelors_degree  masters_degree  professional_degree  doctorate_degree  \
# 0                825             454                   67                26
# 1                693             416                   33               126
# 2                829             377                   41                85
# 3               1144             474                  111               156
# 4                679             181                    7                30
# ..               ...             ...                  ...               ...
# 75               565             349                   85                99
# 76               994             581                  138                76
# 77               786             291                    0                94
# 78               852            1088                   14               114
# 79               600              96                   36                13
#
#     foreign_born  total_pop_nativity  state_y  county  tract_y        GEOID  \
# 0           2062                3387        6       1   403000  06001403000
# 1           1126                3463        6      75    20102  06075020102
# 2            710                2431        6       1   402900  06001402900
# 3           1180                3746        6      75    20900  06075020900
# 4           1189                5146        6      13   308002  06013308002
# ..           ...                 ...      ...     ...      ...          ...
# 75          1413                3428        6      81   606202  06081606202
# 76          1368                5725        6      85   505203  06085505203
# 77          1687                4245        6      81   602300  06081602300
# 78          1922                3907        6      85   508707  06085508707
# 79          1541                4028        6      85   503113  06085503113
#
#       county_name  households_no_vehicle  pct_no_vehicle  pop_nonwhite  \
# 0         Alameda                   1190           58.51          2943
# 1   San Francisco                    699           53.52          2482
# 2         Alameda                   1029           60.00          1770
# 3   San Francisco                    530           32.98          2524
# 4    Contra Costa                     27            1.64          3950
# ..            ...                    ...             ...           ...
# 75      San Mateo                    131           10.84          2796
# 76    Santa Clara                    141            9.28          2931
# 77      San Mateo                     96            6.81          3470
# 78    Santa Clara                    143            9.09          3082
# 79    Santa Clara                    171           13.07          3164
#
#     pct_nonwhite  pct_white  pct_black  pct_asian  poverty_rate  pct_renter  \
# 0          86.89      13.11       9.45      64.30         23.59       82.65
# 1          71.67      28.33       7.85      17.99         27.38       83.08
# 2          72.81      27.19      24.80      28.47         21.31       99.30
# 3          67.38      32.62       1.01      16.34         10.37       86.12
# 4          76.76      23.24      24.37      12.05          8.80       16.57
# ..           ...        ...        ...        ...           ...         ...
# 75         81.56      18.44       0.41      26.28          3.53       60.71
# 76         51.20      48.80       4.37      29.69         27.83       47.33
# 77         81.74      18.26       1.98      30.15         12.38       43.01
# 78         78.88      21.12       0.95      55.59          6.99       58.49
# 79         78.55      21.45       1.19       8.71          4.62       62.84
#
#     pct_owner  pct_transit_commute  pct_drove_alone  pct_bike_commute  \
# 0       17.35                26.52            19.95              0.00
# 1       16.92                18.88            25.90              5.22
# 2        0.70                32.35            19.92              1.27
# 3       13.88                33.15            20.31              5.29
# 4       83.43                 3.79            65.20              0.00
# ..        ...                  ...              ...               ...
# 75      39.29                 4.13            52.61              1.34
# 76      52.67                 7.71            35.82              1.68
# 77      56.99                 4.20            62.53              1.07
# 78      41.51                 4.16            41.05              4.28
# 79      37.16                 1.92            60.84              2.73
#
#     pct_walk_commute  pct_wfh  mean_travel_time_mins  unemployment_rate  \
# 0               8.26    42.62                    NaN               8.86
# 1              14.87    28.00                    NaN              21.67
# 2               5.75    29.81                    NaN               7.46
# 3               4.68    33.84                  19.97               8.03
# 4               0.04    13.24                  45.24               8.18
# ..               ...      ...                    ...                ...
# 75              2.48    19.28                  27.00               2.99
# 76             21.44    26.75                  17.09               5.83
# 77              0.65    17.53                  21.22               2.84
# 78              1.86    35.97                  15.86               6.73
# 79              0.00    13.19                  26.73               2.94
#
#     pop_bachelors_plus  pct_bachelors_plus  pct_foreign_born
# 0                 1372               45.37             60.88
# 1                 1268               43.95             32.52
# 2                 1332               61.04             29.21
# 3                 1885               63.28             31.50
# 4                  897               25.03             23.11
# ..                 ...                 ...               ...
# 75                1098               44.42             41.22
# 76                1789               72.14             23.90
# 77                1171               39.41             39.74
# 78                2068               67.14             49.19
# 79                 745               24.69             38.26
#
# [80 rows x 86 columns]

# %%
transit_census_df.to_csv("../data/transit_census_info.csv")

# %%
transit_census_df[["median_household_income", "median_home_value"]].describe()
# Out:
#        median_household_income  median_home_value
# count                79.000000       7.400000e+01
# mean             141132.987342       1.172900e+06
# std               54480.715792       4.191619e+05
# min               42759.000000       5.591000e+05
# 25%               96424.500000       8.554500e+05
# 50%              136354.000000       1.096500e+06
# 75%              178172.500000       1.522300e+06
# max              250001.000000       2.000001e+06

# %%
transit_census_df.groupby("county_y")['median_household_income'].mean()
# Out:
# county_y
# Contra Costa     90260.500000
# Santa Clara     204222.000000
# alameda         117214.318182
# contracosta     143562.100000
# sanfrancisco    120620.750000
# sanmateo        110206.600000
# Name: median_household_income, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.barplot(data = transit_census_df, x = "name", y = "median_household_income")
ax.set_xticklabels(transit_census_df['name'].values,rotation = 90, fontsize = 6)
plt.show()
# Out:
# /var/folders/z0/pslqf_691f94wn6r6l2rvjgm0000gn/T/ipykernel_47821/3536908204.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(transit_census_df['name'].values,rotation = 90, fontsize = 6)

# %% [markdown]
# Not seeing where Downtown Berkeley BART station (4325) is causing issues. The values appear reasonable. Could the issues be from the older data before updating to 2024-2025?

# %% [markdown]
# ## Visualizations

# %%
census_gdf = gpd.read_file("../data/census_tract_data_2024.csv")

tracts = gpd.read_file("../data/tl_2024_06_tract/tl_2024_06_tract.shp")
tracts = tracts.to_crs(epsg=3857)

bay_fips = ['001','013','041','055','075','081','085','095','097']

bay_tracts = tracts[
    (tracts['STATEFP'] == '06') &
    (tracts['COUNTYFP'].isin(bay_fips))
]

census = bay_tracts[['GEOID', 'geometry']].merge(census_gdf, on="GEOID")
census
# Out:
#             GEOID                                           geometry  \
# 0     06001442700  POLYGON ((-13582893.983 4514550.527, -13582891...
# 1     06001442800  POLYGON ((-13581234.219 4513218.736, -13581226...
# 2     06001442900  POLYGON ((-13579612.516 4512186.349, -13579602...
# 3     06095252204  POLYGON ((-13605096.338 4616602.017, -13605092...
# 4     06095252203  POLYGON ((-13601002.303 4624135.025, -13600142...
# ...           ...                                                ...
# 1767  06013313102  POLYGON ((-13566949.63 4579335.439, -13566947....
# 1768  06013314102  POLYGON ((-13573499.441 4583395.627, -13573496...
# 1769  06013316000  POLYGON ((-13598583.62 4582941.676, -13598476....
# 1770  06013366002  POLYGON ((-13620661.625 4574732.401, -13620650...
# 1771  06013367200  POLYGON ((-13619439.672 4574277.734, -13619438...
#
#                                                    NAME total_pop median_age  \
# 0         Census Tract 4427; Alameda County; California      3068       38.6
# 1         Census Tract 4428; Alameda County; California      3041       40.9
# 2         Census Tract 4429; Alameda County; California      7783       38.3
# 3       Census Tract 2522.04; Solano County; California      5874       41.3
# 4       Census Tract 2522.03; Solano County; California      4299       43.0
# ...                                                 ...       ...        ...
# 1767  Census Tract 3131.02; Contra Costa County; Cal...      4732       37.8
# 1768  Census Tract 3141.02; Contra Costa County; Cal...      6523       37.6
# 1769  Census Tract 3160; Contra Costa County; Califo...      1334       42.1
# 1770  Census Tract 3660.02; Contra Costa County; Cal...      6252       33.8
# 1771  Census Tract 3672; Contra Costa County; Califo...      5617       38.7
#
#      total_pop_race white_alone black_alone aian_alone asian_alone nhpi_alone  \
# 0              3068         945          82          0        1464         27
# 1              3041         846          32         12        1716          0
# 2              7783         924         404         40        4843         13
# 3              5874        2231         660          0        1752         18
# 4              4299        1739         344          0        1249         63
# ...             ...         ...         ...        ...         ...        ...
# 1767           4732         762        1539         69         724          0
# 1768           6523        1169         389         51         820         26
# 1769           1334         518         324          0          51          0
# 1770           6252         608         473        149         502         11
# 1771           5617         733         651         45        1253          0
#
#      other_race_alone two_or_more_races median_household_income  \
# 0                  86               464                209625.0
# 1                 129               306                179844.0
# 2                 760               799                172308.0
# 3                 341               872                199821.0
# 4                  54               850                165078.0
# ...               ...               ...                     ...
# 1767              770               868                 86165.0
# 1768             2737              1331                 97429.0
# 1769              223               218                 58214.0
# 1770             2634              1875                 79355.0
# 1771             2091               844                 95278.0
#
#      per_capita_income total_pop_poverty_calc pop_below_poverty  \
# 0              84305.0                   3057                90
# 1              66720.0                   3031               101
# 2              67357.0                   7778               229
# 3              70224.0                   5862               173
# 4              78127.0                   4296               183
# ...                ...                    ...               ...
# 1767           38276.0                   4619               629
# 1768           33629.0                   6502               467
# 1769           32744.0                   1022               266
# 1770           29450.0                   6252               992
# 1771           37675.0                   5590               762
#
#      total_housing_units total_occupied_units owner_occupied renter_occupied  \
# 0                   1071                 1071            831             240
# 1                    953                  953            750             203
# 2                   2526                 2526           1302            1224
# 3                   1784                 1784           1597             187
# 4                   1709                 1661           1291             370
# ...                  ...                  ...            ...             ...
# 1767                1669                 1611            742             869
# 1768                1957                 1798           1393             405
# 1769                 614                  596            115             481
# 1770                1833                 1808            846             962
# 1771                1798                 1734           1066             668
#
#      total_households owner_occ_no_vehicle renter_occ_no_vehicle  \
# 0                1071                    9                    36
# 1                 953                    8                     5
# 2                2526                   34                     9
# 3                1784                   11                     0
# 4                1661                   14                    47
# ...               ...                  ...                   ...
# 1767             1611                   12                    77
# 1768             1798                   84                    67
# 1769              596                    0                   129
# 1770             1808                   96                   273
# 1771             1734                   63                    96
#
#      median_gross_rent median_home_value total_workers_16plus drove_alone  \
# 0               3222.0         1520500.0                 1499         876
# 1               3250.0         1114100.0                 1457         815
# 2               2946.0         1289900.0                 4067        2068
# 3               3286.0          934500.0                 2556        1738
# 4               2865.0          813100.0                 2258        1575
# ...                ...               ...                  ...         ...
# 1767            2462.0          576400.0                 2307        1943
# 1768            2070.0          499800.0                 3290        2595
# 1769            1557.0                                    419         298
# 1770            1778.0          556500.0                 2788        1683
# 1771            2152.0          602800.0                 2558        1758
#
#      public_transit_commuters bicycle_commuters walked_commuters  \
# 0                           7                 0                0
# 1                          32                 0                8
# 2                         342                28               35
# 3                          36                 4               63
# 4                          24                 0               46
# ...                       ...               ...              ...
# 1767                      181                 0               33
# 1768                      105                 0                0
# 1769                        6                16               54
# 1770                      206                14               83
# 1771                      147                 0                0
#
#      worked_from_home aggregate_travel_time_mins labor_force employed  \
# 0                 358                    32700.0        1569     1537
# 1                 380                                   1649     1522
# 2                1302                    89190.0        4512     4188
# 3                 501                    68510.0        2823     2543
# 4                 440                    51425.0        2353     2288
# ...               ...                        ...         ...      ...
# 1767               57                    89740.0        2717     2409
# 1768              116                   133255.0        3522     3301
# 1769               32                                    525      448
# 1770              226                    79065.0        3244     3025
# 1771              235                    83030.0        2962     2683
#
#      unemployed pop_25plus bachelors_degree masters_degree  \
# 0            32       2165              699            559
# 1           127       2275              775            342
# 2           324       5560             2073           1224
# 3           230       3637             1095            571
# 4            34       3100              814            539
# ...         ...        ...              ...            ...
# 1767        308       3255              344            165
# 1768        189       4342              357             30
# 1769         77       1068              192             59
# 1770        219       3887              446             62
# 1771        279       3998              501            222
#
#      professional_degree doctorate_degree foreign_born total_pop_nativity  \
# 0                     89              101         1387               3068
# 1                     40               49         1465               3041
# 2                     93               77         3754               7783
# 3                     73               81         1043               5874
# 4                    132              133          621               4299
# ...                  ...              ...          ...                ...
# 1767                   0               17         1315               4732
# 1768                  25                0         2598               6523
# 1769                   0               11          155               1334
# 1770                  16               25         2448               6252
# 1771                  64               83         2408               5617
#
#      state county   tract   county_name households_no_vehicle pct_no_vehicle  \
# 0       06    001  442700       Alameda                    45            4.2
# 1       06    001  442800       Alameda                    13           1.36
# 2       06    001  442900       Alameda                    43            1.7
# 3       06    095  252204        Solano                    11           0.62
# 4       06    095  252203        Solano                    61           3.67
# ...    ...    ...     ...           ...                   ...            ...
# 1767    06    013  313102  Contra Costa                    89           5.52
# 1768    06    013  314102  Contra Costa                   151            8.4
# 1769    06    013  316000  Contra Costa                   129          21.64
# 1770    06    013  366002  Contra Costa                   369          20.41
# 1771    06    013  367200  Contra Costa                   159           9.17
#
#      pop_nonwhite pct_nonwhite pct_white pct_black pct_asian poverty_rate  \
# 0            2123         69.2      30.8      2.67     47.72         2.94
# 1            2195        72.18     27.82      1.05     56.43         3.33
# 2            6859        88.13     11.87      5.19     62.23         2.94
# 3            3643        62.02     37.98     11.24     29.83         2.95
# 4            2560        59.55     40.45       8.0     29.05         4.26
# ...           ...          ...       ...       ...       ...          ...
# 1767         3970         83.9      16.1     32.52      15.3        13.62
# 1768         5354        82.08     17.92      5.96     12.57         7.18
# 1769          816        61.17     38.83     24.29      3.82        26.03
# 1770         5644        90.28      9.72      7.57      8.03        15.87
# 1771         4884        86.95     13.05     11.59     22.31        13.63
#
#      pct_renter pct_owner pct_transit_commute pct_drove_alone  \
# 0         22.41     77.59                0.47           58.44
# 1          21.3      78.7                 2.2           55.94
# 2         48.46     51.54                8.41           50.85
# 3         10.48     89.52                1.41            68.0
# 4         22.28     77.72                1.06           69.75
# ...         ...       ...                 ...             ...
# 1767      53.94     46.06                7.85           84.22
# 1768      22.53     77.47                3.19           78.88
# 1769       80.7      19.3                1.43           71.12
# 1770      53.21     46.79                7.39           60.37
# 1771      38.52     61.48                5.75           68.73
#
#      pct_bike_commute pct_walk_commute pct_wfh mean_travel_time_mins  \
# 0                 0.0              0.0   23.88                 21.81
# 1                 0.0             0.55   26.08
# 2                0.69             0.86   32.01                 21.93
# 3                0.16             2.46    19.6                  26.8
# 4                 0.0             2.04   19.49                 22.77
# ...               ...              ...     ...                   ...
# 1767              0.0             1.43    2.47                  38.9
# 1768              0.0              0.0    3.53                  40.5
# 1769             3.82            12.89    7.64
# 1770              0.5             2.98    8.11                 28.36
# 1771              0.0              0.0    9.19                 32.46
#
#      unemployment_rate pop_bachelors_plus pct_bachelors_plus pct_foreign_born
# 0                 2.04               1448              66.88            45.21
# 1                  7.7               1206              53.01            48.17
# 2                 7.18               3467              62.36            48.23
# 3                 8.15               1820              50.04            17.76
# 4                 1.44               1618              52.19            14.45
# ...                ...                ...                ...              ...
# 1767             11.34                526              16.16            27.79
# 1768              5.37                412               9.49            39.83
# 1769             14.67                262              24.53            11.62
# 1770              6.75                549              14.12            39.16
# 1771              9.42                870              21.76            42.87
#
# [1772 rows x 67 columns]

# %%
mapping = pd.merge(transit, classification[['station_id', 'station_type', 'avg_weekday_exits']], how = "inner", left_on = 'name', 
         right_on='station_id')
mapping
# Out:
#     Unnamed: 0 station_id_x                                  name   latitude  \
# 0            0         12TH          12th St. Oakland City Center  37.803768
# 1            1         16TH                      16th St. Mission  37.765062
# 2            2         19TH                      19th St. Oakland  37.808350
# 3            3         24TH                      24th St. Mission  37.752470
# 4            4         ANTC                               Antioch  37.995388
# ..         ...          ...                                   ...        ...
# 75          75    san_mateo                             San Mateo  37.568240
# 76          76  santa_clara          Santa Clara Caltrain Station  37.353384
# 77          77     south_sf  South San Francisco Caltrain Station  37.655941
# 78          79    sunnyvale                             Sunnyvale  37.378934
# 79          80       tamien               Tamien Caltrain Station  37.312690
#
#      longitude                  address           city        county  zipcode  \
# 0  -122.271450            1245 Broadway        Oakland       alameda  94612.0
# 1  -122.419694      2000 Mission Street  San Francisco  sanfrancisco  94110.0
# 2  -122.268602            1900 Broadway        Oakland       alameda  94612.0
# 3  -122.418143      2800 Mission Street  San Francisco  sanfrancisco  94110.0
# 4  -121.780420  1600 Slatten Ranch Road        Antioch  Contra Costa  94509.0
# ..         ...                      ...            ...           ...      ...
# 75 -122.323900                      NaN            NaN           NaN      NaN
# 76 -121.936465                      NaN            NaN           NaN      NaN
# 77 -122.404979                      NaN            NaN           NaN      NaN
# 78 -122.031500                      NaN            NaN           NaN      NaN
# 79 -121.884700                      NaN            NaN           NaN      NaN
#
#       agency           mode                             geometry  \
# 0       BART     Heavy Rail         POINT (-122.27145 37.803768)
# 1       BART     Heavy Rail        POINT (-122.419694 37.765062)
# 2       BART     Heavy Rail         POINT (-122.268602 37.80835)
# 3       BART     Heavy Rail         POINT (-122.418143 37.75247)
# 4       BART     Heavy Rail         POINT (-121.78042 37.995388)
# ..       ...            ...                                  ...
# 75  Caltrain  Commuter Rail           POINT (-122.3239 37.56824)
# 76  Caltrain  Commuter Rail        POINT (-121.936465 37.353384)
# 77  Caltrain  Commuter Rail  POINT (-122.404979006 37.655941416)
# 78  Caltrain  Commuter Rail          POINT (-122.0315 37.378934)
# 79  Caltrain  Commuter Rail           POINT (-121.8847 37.31269)
#
#                             station_id_y station_type  avg_weekday_exits
# 0           12th St. Oakland City Center         core               5164
# 1                       16th St. Mission         core               5642
# 2                       19th St. Oakland         core               4606
# 3                       24th St. Mission         core               5491
# 4                                Antioch   peripheral                523
# ..                                   ...          ...                ...
# 75                             San Mateo   peripheral               1270
# 76          Santa Clara Caltrain Station   peripheral                839
# 77  South San Francisco Caltrain Station   peripheral                692
# 78                             Sunnyvale   peripheral               1770
# 79               Tamien Caltrain Station   peripheral                243
#
# [80 rows x 15 columns]

# %%
sns.boxplot(data = mapping, x = "agency", y="avg_weekday_exits")
# Out:
# <Axes: xlabel='agency', ylabel='avg_weekday_exits'>

# %%
census_transit_class = pd.merge(transit_census_df, classification[['station_id', 'station_type', 'avg_weekday_exits']], how = "inner", left_on = 'station', 
         right_on='station_id')
census_transit_class.head()
# Out:
#                         station        geoid state_x county_x tract_x  \
# 0  12th St. Oakland City Center  06001403000      06      001  403000
# 1              16th St. Mission  06075020102      06      075  020102
# 2              19th St. Oakland  06001402900      06      001  402900
# 3              24th St. Mission  06075020900      06      075  020900
# 4                       Antioch  06013308002      06      013  308002
#
#              tract_name  Unnamed: 0 station_id_x  \
# 0     Census Tract 4030           0         12TH
# 1   Census Tract 201.02           1         16TH
# 2     Census Tract 4029           2         19TH
# 3      Census Tract 209           3         24TH
# 4  Census Tract 3080.02           4         ANTC
#
#                            name   latitude   longitude  \
# 0  12th St. Oakland City Center  37.803768 -122.271450
# 1              16th St. Mission  37.765062 -122.419694
# 2              19th St. Oakland  37.808350 -122.268602
# 3              24th St. Mission  37.752470 -122.418143
# 4                       Antioch  37.995388 -121.780420
#
#                    address           city      county_y  zipcode agency  \
# 0            1245 Broadway        Oakland       alameda  94612.0   BART
# 1      2000 Mission Street  San Francisco  sanfrancisco  94110.0   BART
# 2            1900 Broadway        Oakland       alameda  94612.0   BART
# 3      2800 Mission Street  San Francisco  sanfrancisco  94110.0   BART
# 4  1600 Slatten Ranch Road        Antioch  Contra Costa  94509.0   BART
#
#          mode                       geometry                  station_id_y  \
# 0  Heavy Rail   POINT (-122.27145 37.803768)  12th St. Oakland City Center
# 1  Heavy Rail  POINT (-122.419694 37.765062)              16th St. Mission
# 2  Heavy Rail   POINT (-122.268602 37.80835)              19th St. Oakland
# 3  Heavy Rail   POINT (-122.418143 37.75247)              24th St. Mission
# 4  Heavy Rail   POINT (-121.78042 37.995388)                       Antioch
#
#   station_type_x                                               NAME  \
# 0           core      Census Tract 4030; Alameda County; California
# 1           core  Census Tract 201.02; San Francisco County; Cal...
# 2           core      Census Tract 4029; Alameda County; California
# 3           core  Census Tract 209; San Francisco County; Califo...
# 4     peripheral  Census Tract 3080.02; Contra Costa County; Cal...
#
#    total_pop  median_age  total_pop_race  white_alone  black_alone  \
# 0       3387        40.4            3387          444          320
# 1       3463        45.0            3463          981          272
# 2       2431        37.2            2431          661          603
# 3       3746        38.4            3746         1222           38
# 4       5146        39.9            5146         1196         1254
#
#    aian_alone  asian_alone  nhpi_alone  other_race_alone  two_or_more_races  \
# 0           2         2178          48                48                347
# 1          57          623           0              1009                521
# 2          10          692           0               112                353
# 3          33          612           0              1170                671
# 4         155          620          22               935                964
#
#    median_household_income  per_capita_income  total_pop_poverty_calc  \
# 0                  58794.0            60439.0                    3387
# 1                 100761.0            55597.0                    3463
# 2                  66050.0            89947.0                    2417
# 3                  96250.0            67562.0                    3733
# 4                 119896.0            50923.0                    5134
#
#    pop_below_poverty  total_housing_units  total_occupied_units  \
# 0                799                 2413                  2034
# 1                948                 1861                  1306
# 2                515                 2071                  1715
# 3                387                 1898                  1607
# 4                452                 1669                  1648
#
#    owner_occupied  renter_occupied  total_households  owner_occ_no_vehicle  \
# 0             353             1681              2034                   182
# 1             221             1085              1306                    60
# 2              12             1703              1715                     0
# 3             223             1384              1607                    50
# 4            1375              273              1648                    12
#
#    renter_occ_no_vehicle  median_gross_rent  median_home_value  \
# 0                   1008             2128.0           573000.0
# 1                    639             1764.0          1098000.0
# 2                   1029             2096.0                NaN
# 3                    480             2446.0          1296100.0
# 4                     15             2585.0           726400.0
#
#    total_workers_16plus  drove_alone  public_transit_commuters  \
# 0                  1659          331                       440
# 1                  1668          432                       315
# 2                  1496          298                       484
# 3                  2157          438                       715
# 4                  2477         1615                        94
#
#    bicycle_commuters  walked_commuters  worked_from_home  \
# 0                  0               137               707
# 1                 87               248               467
# 2                 19                86               446
# 3                114               101               730
# 4                  0                 1               328
#
#    aggregate_travel_time_mins  labor_force  employed  unemployed  pop_25plus  \
# 0                         NaN         1931      1760         171        3024
# 1                         NaN         2150      1684         466        2885
# 2                         NaN         1648      1525         123        2182
# 3                     43075.0         2478      2279         199        2979
# 4                    112050.0         2752      2527         225        3583
#
#    bachelors_degree  masters_degree  professional_degree  doctorate_degree  \
# 0               825             454                   67                26
# 1               693             416                   33               126
# 2               829             377                   41                85
# 3              1144             474                  111               156
# 4               679             181                    7                30
#
#    foreign_born  total_pop_nativity  state_y  county  tract_y        GEOID  \
# 0          2062                3387        6       1   403000  06001403000
# 1          1126                3463        6      75    20102  06075020102
# 2           710                2431        6       1   402900  06001402900
# 3          1180                3746        6      75    20900  06075020900
# 4          1189                5146        6      13   308002  06013308002
#
#      county_name  households_no_vehicle  pct_no_vehicle  pop_nonwhite  \
# 0        Alameda                   1190           58.51          2943
# 1  San Francisco                    699           53.52          2482
# 2        Alameda                   1029           60.00          1770
# 3  San Francisco                    530           32.98          2524
# 4   Contra Costa                     27            1.64          3950
#
#    pct_nonwhite  pct_white  pct_black  pct_asian  poverty_rate  pct_renter  \
# 0         86.89      13.11       9.45      64.30         23.59       82.65
# 1         71.67      28.33       7.85      17.99         27.38       83.08
# 2         72.81      27.19      24.80      28.47         21.31       99.30
# 3         67.38      32.62       1.01      16.34         10.37       86.12
# 4         76.76      23.24      24.37      12.05          8.80       16.57
#
#    pct_owner  pct_transit_commute  pct_drove_alone  pct_bike_commute  \
# 0      17.35                26.52            19.95              0.00
# 1      16.92                18.88            25.90              5.22
# 2       0.70                32.35            19.92              1.27
# 3      13.88                33.15            20.31              5.29
# 4      83.43                 3.79            65.20              0.00
#
#    pct_walk_commute  pct_wfh  mean_travel_time_mins  unemployment_rate  \
# 0              8.26    42.62                    NaN               8.86
# 1             14.87    28.00                    NaN              21.67
# 2              5.75    29.81                    NaN               7.46
# 3              4.68    33.84                  19.97               8.03
# 4              0.04    13.24                  45.24               8.18
#
#    pop_bachelors_plus  pct_bachelors_plus  pct_foreign_born  \
# 0                1372               45.37             60.88
# 1                1268               43.95             32.52
# 2                1332               61.04             29.21
# 3                1885               63.28             31.50
# 4                 897               25.03             23.11
#
#                      station_id station_type_y  avg_weekday_exits
# 0  12th St. Oakland City Center           core               5164
# 1              16th St. Mission           core               5642
# 2              19th St. Oakland           core               4606
# 3              24th St. Mission           core               5491
# 4                       Antioch     peripheral                523

# %%
sns.scatterplot(
    x="total_pop",
    y="avg_weekday_exits",
    hue="agency",
    data = census_transit_class
)
# Out:
# <Axes: xlabel='total_pop', ylabel='avg_weekday_exits'>

# %%
sns.scatterplot(
    x="median_household_income",
    y="avg_weekday_exits",
    hue="agency",
    data = census_transit_class
)
# Out:
# <Axes: xlabel='median_household_income', ylabel='avg_weekday_exits'>

# %%
full = census_transit_class.merge(census[['GEOID', 'geometry']], how = 'left', left_on='geoid', right_on='GEOID')
full
# Out:
#                                  station        geoid state_x county_x  \
# 0           12th St. Oakland City Center  06001403000      06      001
# 1                       16th St. Mission  06075020102      06      075
# 2                       19th St. Oakland  06001402900      06      001
# 3                       24th St. Mission  06075020900      06      075
# 4                                Antioch  06013308002      06      013
# ..                                   ...          ...     ...      ...
# 75                             San Mateo  06081606202      06      081
# 76          Santa Clara Caltrain Station  06085505203      06      085
# 77  South San Francisco Caltrain Station  06081602300      06      081
# 78                             Sunnyvale  06085508707      06      085
# 79               Tamien Caltrain Station  06085503113      06      085
#
#    tract_x            tract_name  Unnamed: 0 station_id_x  \
# 0   403000     Census Tract 4030           0         12TH
# 1   020102   Census Tract 201.02           1         16TH
# 2   402900     Census Tract 4029           2         19TH
# 3   020900      Census Tract 209           3         24TH
# 4   308002  Census Tract 3080.02           4         ANTC
# ..     ...                   ...         ...          ...
# 75  606202  Census Tract 6062.02          75    san_mateo
# 76  505203  Census Tract 5052.03          76  santa_clara
# 77  602300     Census Tract 6023          77     south_sf
# 78  508707  Census Tract 5087.07          79    sunnyvale
# 79  503113  Census Tract 5031.13          80       tamien
#
#                                     name   latitude   longitude  \
# 0           12th St. Oakland City Center  37.803768 -122.271450
# 1                       16th St. Mission  37.765062 -122.419694
# 2                       19th St. Oakland  37.808350 -122.268602
# 3                       24th St. Mission  37.752470 -122.418143
# 4                                Antioch  37.995388 -121.780420
# ..                                   ...        ...         ...
# 75                             San Mateo  37.568240 -122.323900
# 76          Santa Clara Caltrain Station  37.353384 -121.936465
# 77  South San Francisco Caltrain Station  37.655941 -122.404979
# 78                             Sunnyvale  37.378934 -122.031500
# 79               Tamien Caltrain Station  37.312690 -121.884700
#
#                     address           city      county_y  zipcode    agency  \
# 0             1245 Broadway        Oakland       alameda  94612.0      BART
# 1       2000 Mission Street  San Francisco  sanfrancisco  94110.0      BART
# 2             1900 Broadway        Oakland       alameda  94612.0      BART
# 3       2800 Mission Street  San Francisco  sanfrancisco  94110.0      BART
# 4   1600 Slatten Ranch Road        Antioch  Contra Costa  94509.0      BART
# ..                      ...            ...           ...      ...       ...
# 75                      NaN            NaN           NaN      NaN  Caltrain
# 76                      NaN            NaN           NaN      NaN  Caltrain
# 77                      NaN            NaN           NaN      NaN  Caltrain
# 78                      NaN            NaN           NaN      NaN  Caltrain
# 79                      NaN            NaN           NaN      NaN  Caltrain
#
#              mode                           geometry_x  \
# 0      Heavy Rail         POINT (-122.27145 37.803768)
# 1      Heavy Rail        POINT (-122.419694 37.765062)
# 2      Heavy Rail         POINT (-122.268602 37.80835)
# 3      Heavy Rail         POINT (-122.418143 37.75247)
# 4      Heavy Rail         POINT (-121.78042 37.995388)
# ..            ...                                  ...
# 75  Commuter Rail           POINT (-122.3239 37.56824)
# 76  Commuter Rail        POINT (-121.936465 37.353384)
# 77  Commuter Rail  POINT (-122.404979006 37.655941416)
# 78  Commuter Rail          POINT (-122.0315 37.378934)
# 79  Commuter Rail           POINT (-121.8847 37.31269)
#
#                             station_id_y station_type_x  \
# 0           12th St. Oakland City Center           core
# 1                       16th St. Mission           core
# 2                       19th St. Oakland           core
# 3                       24th St. Mission           core
# 4                                Antioch     peripheral
# ..                                   ...            ...
# 75                             San Mateo     peripheral
# 76          Santa Clara Caltrain Station     peripheral
# 77  South San Francisco Caltrain Station     peripheral
# 78                             Sunnyvale     peripheral
# 79               Tamien Caltrain Station     peripheral
#
#                                                  NAME  total_pop  median_age  \
# 0       Census Tract 4030; Alameda County; California       3387        40.4
# 1   Census Tract 201.02; San Francisco County; Cal...       3463        45.0
# 2       Census Tract 4029; Alameda County; California       2431        37.2
# 3   Census Tract 209; San Francisco County; Califo...       3746        38.4
# 4   Census Tract 3080.02; Contra Costa County; Cal...       5146        39.9
# ..                                                ...        ...         ...
# 75  Census Tract 6062.02; San Mateo County; Califo...       3428        33.1
# 76  Census Tract 5052.03; Santa Clara County; Cali...       5725        22.5
# 77    Census Tract 6023; San Mateo County; California       4245        37.9
# 78  Census Tract 5087.07; Santa Clara County; Cali...       3907        33.1
# 79  Census Tract 5031.13; Santa Clara County; Cali...       4028        35.9
#
#     total_pop_race  white_alone  black_alone  aian_alone  asian_alone  \
# 0             3387          444          320           2         2178
# 1             3463          981          272          57          623
# 2             2431          661          603          10          692
# 3             3746         1222           38          33          612
# 4             5146         1196         1254         155          620
# ..             ...          ...          ...         ...          ...
# 75            3428          632           14           0          901
# 76            5725         2794          250          23         1700
# 77            4245          775           84           0         1280
# 78            3907          825           37          43         2172
# 79            4028          864           48          53          351
#
#     nhpi_alone  other_race_alone  two_or_more_races  median_household_income  \
# 0           48                48                347                  58794.0
# 1            0              1009                521                 100761.0
# 2            0               112                353                  66050.0
# 3            0              1170                671                  96250.0
# 4           22               935                964                 119896.0
# ..         ...               ...                ...                      ...
# 75          15               957                909                 138250.0
# 76          35               213                710                 139028.0
# 77         157               759               1190                 146750.0
# 78           0               341                489                 173165.0
# 79           0              1963                749                  95625.0
#
#     per_capita_income  total_pop_poverty_calc  pop_below_poverty  \
# 0             60439.0                    3387                799
# 1             55597.0                    3463                948
# 2             89947.0                    2417                515
# 3             67562.0                    3733                387
# 4             50923.0                    5134                452
# ..                ...                     ...                ...
# 75            77701.0                    3399                120
# 76            54862.0                    3500                974
# 77            66247.0                    4240                525
# 78           103876.0                    3907                273
# 79            44893.0                    4028                186
#
#     total_housing_units  total_occupied_units  owner_occupied  \
# 0                  2413                  2034             353
# 1                  1861                  1306             221
# 2                  2071                  1715              12
# 3                  1898                  1607             223
# 4                  1669                  1648            1375
# ..                  ...                   ...             ...
# 75                 1262                  1209             475
# 76                 1593                  1519             800
# 77                 1553                  1409             803
# 78                 1698                  1573             653
# 79                 1337                  1308             486
#
#     renter_occupied  total_households  owner_occ_no_vehicle  \
# 0              1681              2034                   182
# 1              1085              1306                    60
# 2              1703              1715                     0
# 3              1384              1607                    50
# 4               273              1648                    12
# ..              ...               ...                   ...
# 75              734              1209                    15
# 76              719              1519                    38
# 77              606              1409                    52
# 78              920              1573                    21
# 79              822              1308                    21
#
#     renter_occ_no_vehicle  median_gross_rent  median_home_value  \
# 0                    1008             2128.0           573000.0
# 1                     639             1764.0          1098000.0
# 2                    1029             2096.0                NaN
# 3                     480             2446.0          1296100.0
# 4                      15             2585.0           726400.0
# ..                    ...                ...                ...
# 75                    116             3062.0          1092900.0
# 76                    103             3266.0          1198700.0
# 77                     44             3054.0          1144800.0
# 78                    122             2639.0          1530200.0
# 79                    150             2048.0          1065000.0
#
#     total_workers_16plus  drove_alone  public_transit_commuters  \
# 0                   1659          331                       440
# 1                   1668          432                       315
# 2                   1496          298                       484
# 3                   2157          438                       715
# 4                   2477         1615                        94
# ..                   ...          ...                       ...
# 75                  1935         1018                        80
# 76                  2920         1046                       225
# 77                  2618         1637                       110
# 78                  2524         1036                       105
# 79                  2237         1361                        43
#
#     bicycle_commuters  walked_commuters  worked_from_home  \
# 0                   0               137               707
# 1                  87               248               467
# 2                  19                86               446
# 3                 114               101               730
# 4                   0                 1               328
# ..                ...               ...               ...
# 75                 26                48               373
# 76                 49               626               781
# 77                 28                17               459
# 78                108                47               908
# 79                 61                 0               295
#
#     aggregate_travel_time_mins  labor_force  employed  unemployed  pop_25plus  \
# 0                          NaN         1931      1760         171        3024
# 1                          NaN         2150      1684         466        2885
# 2                          NaN         1648      1525         123        2182
# 3                      43075.0         2478      2279         199        2979
# 4                     112050.0         2752      2527         225        3583
# ..                         ...          ...       ...         ...         ...
# 75                     52240.0         2043      1982          61        2472
# 76                     49895.0         3275      3084         191        2480
# 77                     55550.0         2778      2699          79        2971
# 78                     40040.0         2747      2562         185        3080
# 79                     59800.0         2343      2274          69        3017
#
#     bachelors_degree  masters_degree  professional_degree  doctorate_degree  \
# 0                825             454                   67                26
# 1                693             416                   33               126
# 2                829             377                   41                85
# 3               1144             474                  111               156
# 4                679             181                    7                30
# ..               ...             ...                  ...               ...
# 75               565             349                   85                99
# 76               994             581                  138                76
# 77               786             291                    0                94
# 78               852            1088                   14               114
# 79               600              96                   36                13
#
#     foreign_born  total_pop_nativity  state_y  county  tract_y      GEOID_x  \
# 0           2062                3387        6       1   403000  06001403000
# 1           1126                3463        6      75    20102  06075020102
# 2            710                2431        6       1   402900  06001402900
# 3           1180                3746        6      75    20900  06075020900
# 4           1189                5146        6      13   308002  06013308002
# ..           ...                 ...      ...     ...      ...          ...
# 75          1413                3428        6      81   606202  06081606202
# 76          1368                5725        6      85   505203  06085505203
# 77          1687                4245        6      81   602300  06081602300
# 78          1922                3907        6      85   508707  06085508707
# 79          1541                4028        6      85   503113  06085503113
#
#       county_name  households_no_vehicle  pct_no_vehicle  pop_nonwhite  \
# 0         Alameda                   1190           58.51          2943
# 1   San Francisco                    699           53.52          2482
# 2         Alameda                   1029           60.00          1770
# 3   San Francisco                    530           32.98          2524
# 4    Contra Costa                     27            1.64          3950
# ..            ...                    ...             ...           ...
# 75      San Mateo                    131           10.84          2796
# 76    Santa Clara                    141            9.28          2931
# 77      San Mateo                     96            6.81          3470
# 78    Santa Clara                    143            9.09          3082
# 79    Santa Clara                    171           13.07          3164
#
#     pct_nonwhite  pct_white  pct_black  pct_asian  poverty_rate  pct_renter  \
# 0          86.89      13.11       9.45      64.30         23.59       82.65
# 1          71.67      28.33       7.85      17.99         27.38       83.08
# 2          72.81      27.19      24.80      28.47         21.31       99.30
# 3          67.38      32.62       1.01      16.34         10.37       86.12
# 4          76.76      23.24      24.37      12.05          8.80       16.57
# ..           ...        ...        ...        ...           ...         ...
# 75         81.56      18.44       0.41      26.28          3.53       60.71
# 76         51.20      48.80       4.37      29.69         27.83       47.33
# 77         81.74      18.26       1.98      30.15         12.38       43.01
# 78         78.88      21.12       0.95      55.59          6.99       58.49
# 79         78.55      21.45       1.19       8.71          4.62       62.84
#
#     pct_owner  pct_transit_commute  pct_drove_alone  pct_bike_commute  \
# 0       17.35                26.52            19.95              0.00
# 1       16.92                18.88            25.90              5.22
# 2        0.70                32.35            19.92              1.27
# 3       13.88                33.15            20.31              5.29
# 4       83.43                 3.79            65.20              0.00
# ..        ...                  ...              ...               ...
# 75      39.29                 4.13            52.61              1.34
# 76      52.67                 7.71            35.82              1.68
# 77      56.99                 4.20            62.53              1.07
# 78      41.51                 4.16            41.05              4.28
# 79      37.16                 1.92            60.84              2.73
#
#     pct_walk_commute  pct_wfh  mean_travel_time_mins  unemployment_rate  \
# 0               8.26    42.62                    NaN               8.86
# 1              14.87    28.00                    NaN              21.67
# 2               5.75    29.81                    NaN               7.46
# 3               4.68    33.84                  19.97               8.03
# 4               0.04    13.24                  45.24               8.18
# ..               ...      ...                    ...                ...
# 75              2.48    19.28                  27.00               2.99
# 76             21.44    26.75                  17.09               5.83
# 77              0.65    17.53                  21.22               2.84
# 78              1.86    35.97                  15.86               6.73
# 79              0.00    13.19                  26.73               2.94
#
#     pop_bachelors_plus  pct_bachelors_plus  pct_foreign_born  \
# 0                 1372               45.37             60.88
# 1                 1268               43.95             32.52
# 2                 1332               61.04             29.21
# 3                 1885               63.28             31.50
# 4                  897               25.03             23.11
# ..                 ...                 ...               ...
# 75                1098               44.42             41.22
# 76                1789               72.14             23.90
# 77                1171               39.41             39.74
# 78                2068               67.14             49.19
# 79                 745               24.69             38.26
#
#                               station_id station_type_y  avg_weekday_exits  \
# 0           12th St. Oakland City Center           core               5164
# 1                       16th St. Mission           core               5642
# 2                       19th St. Oakland           core               4606
# 3                       24th St. Mission           core               5491
# 4                                Antioch     peripheral                523
# ..                                   ...            ...                ...
# 75                             San Mateo     peripheral               1270
# 76          Santa Clara Caltrain Station     peripheral                839
# 77  South San Francisco Caltrain Station     peripheral                692
# 78                             Sunnyvale     peripheral               1770
# 79               Tamien Caltrain Station     peripheral                243
#
#         GEOID_y                                         geometry_y
# 0   06001403000  POLYGON ((-13611590.818 4550988.94, -13611580....
# 1   06075020102  POLYGON ((-13627959.726 4546498.189, -13627902...
# 2   06001402900  POLYGON ((-13611176.038 4551825.521, -13611160...
# 3   06075020900  POLYGON ((-13627839.507 4544914.79, -13627716....
# 4   06013308002  POLYGON ((-13557192.687 4579164.79, -13556856....
# ..          ...                                                ...
# 75  06081606202  POLYGON ((-13617244.772 4518845.876, -13617243...
# 76  06085505203  POLYGON ((-13574682.99 4488027.588, -13574671....
# 77  06081602300  POLYGON ((-13629320.071 4530830.774, -13629316...
# 78  06085508707  POLYGON ((-13584716.215 4492158.058, -13584711...
# 79  06085503113  POLYGON ((-13568417.04 4483223.803, -13568376....
#
# [80 rows x 91 columns]

# %%
full_gdf = gpd.GeoDataFrame(
    full, 
    geometry= 'geometry_y',
    crs="EPSG:3857" # WGS84
)

# %% [markdown]
# ### Missing Data

# %%
variables = ["median_household_income", 
             "pct_no_vehicle", 
             "pct_nonwhite", 
             "pct_transit_commute", 
             "avg_weekday_exits"]
for var in variables:
    print(f"{var}: {full_gdf[full_gdf[var].isnull()]['station']}")
# Out:
# median_household_income: 41    San Francisco International Airport
# Name: station, dtype: str
# pct_no_vehicle: 41    San Francisco International Airport
# Name: station, dtype: str
# pct_nonwhite: 41    San Francisco International Airport
# Name: station, dtype: str
# pct_transit_commute: 41    San Francisco International Airport
# Name: station, dtype: str
# avg_weekday_exits: Series([], Name: station, dtype: str)

# %%
fig, ax = plt.subplots(figsize=(12, 8))
census.plot(ax = ax, color="#F0EDE8", edgecolor="#DDD9D3")
full_gdf.plot(ax = ax, column="median_household_income", cmap="viridis", legend = True)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(12, 8))
census.plot(ax = ax, color="#F0EDE8", edgecolor="#DDD9D3")
full_gdf.plot(ax = ax, column="pct_nonwhite", cmap="viridis", legend = True)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(12, 8))
census.plot(ax = ax, color="#F0EDE8", edgecolor="#DDD9D3")
full_gdf.plot(ax = ax, column="pct_transit_commute", cmap="viridis", legend = True)
# Out:
# <Axes: >

# %%
full_gdf.explore(column="median_household_income", cmap="viridis", legend = True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f08f0ce816c31869b08b1a74d8a5517c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f08f0ce816c31869b08b1a74d8a5517c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f08f0ce816c31869b08b1a74d8a5517c = L.map(
#                 &quot;map_f08f0ce816c31869b08b1a74d8a5517c&quot;,
#                 {
#                     center: [37.50538604206661, -122.00941321609184],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_f08f0ce816c31869b08b1a74d8a5517c);
#
#
#
#
#
#             var tile_layer_ac89489578bbfbcee3b37ba25a81fa3a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ac89489578bbfbcee3b37ba25a81fa3a.addTo(map_f08f0ce816c31869b08b1a74d8a5517c);
#
#
#             map_f08f0ce816c31869b08b1a74d8a5517c.fitBounds(
#                 [[36.986750863334706, -122.47172537037447], [38.02402122079852, -121.54710106180923]],
#                 {}
#             );
#
#
#         function geo_json_7e866b21e4602e0ca2dfb9249dfe1fb6_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#481c6e&quot;, &quot;fillColor&quot;: &quot;#481c6e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;40&quot;:
#                     return {&quot;color&quot;: &quot;#375a8c&quot;, &quot;fillColor&quot;: &quot;#375a8c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#482878&quot;, &quot;fillColor&quot;: &quot;#482878&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;23&quot;: case &quot;26&quot;:
#                     return {&quot;color&quot;: &quot;#3a548c&quot;, &quot;fillColor&quot;: &quot;#3a548c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#2c718e&quot;, &quot;fillColor&quot;: &quot;#2c718e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;31&quot;:
#                     return {&quot;color&quot;: &quot;#25848e&quot;, &quot;fillColor&quot;: &quot;#25848e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#2b748e&quot;, &quot;fillColor&quot;: &quot;#2b748e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#3d4d8a&quot;, &quot;fillColor&quot;: &quot;#3d4d8a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#306a8e&quot;, &quot;fillColor&quot;: &quot;#306a8e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#39568c&quot;, &quot;fillColor&quot;: &quot;#39568c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;#2cb17e&quot;, &quot;fillColor&quot;: &quot;#2cb17e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;#3c508b&quot;, &quot;fillColor&quot;: &quot;#3c508b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;15&quot;:
#                     return {

# %%
full_gdf.columns
# Out:
# Index(['station', 'geoid', 'state_x', 'county_x', 'tract_x', 'tract_name',
#        'Unnamed: 0', 'station_id_x', 'name', 'latitude', 'longitude',
#        'address', 'city', 'county_y', 'zipcode', 'agency', 'mode',
#        'geometry_x', 'station_id_y', 'station_type_x', 'NAME', 'total_pop',
#        'median_age', 'total_pop_race', 'white_alone', 'black_alone',
#        'aian_alone', 'asian_alone', 'nhpi_alone', 'other_race_alone',
#        'two_or_more_races', 'median_household_income', 'per_capita_income',
#        'total_pop_poverty_calc', 'pop_below_poverty', 'total_housing_units',
#        'total_occupied_units', 'owner_occupied', 'renter_occupied',
#        'total_households', 'owner_occ_no_vehicle', 'renter_occ_no_vehicle',
#        'median_gross_rent', 'median_home_value', 'total_workers_16plus',
#        'drove_alone', 'public_transit_commuters', 'bicycle_commuters',
#        'walked_commuters', 'worked_from_home', 'aggregate_travel_time_mins',
#        'labor_force', 'employed', 'unemployed', 'pop_25plus',
#        'bachelors_degree', 'masters_degree', 'professional_degree',
#        'doctorate_degree', 'foreign_born', 'total_pop_nativity', 'state_y',
#        'county', 'tract_y', 'GEOID_x', 'county_name', 'households_no_vehicle',
#        'pct_no_vehicle', 'pop_nonwhite', 'pct_nonwhite', 'pct_white',
#        'pct_black', 'pct_asian', 'poverty_rate', 'pct_renter', 'pct_owner',
#        'pct_transit_commute', 'pct_drove_alone', 'pct_bike_commute',
#        'pct_walk_commute', 'pct_wfh', 'mean_travel_time_mins',
#        'unemployment_rate', 'pop_bachelors_plus', 'pct_bachelors_plus',
#        'pct_foreign_born', 'station_id', 'station_type_y', 'avg_weekday_exits',
#        'GEOID_y', 'geometry_y'],
#       dtype='str')

# %%
variables = ["median_household_income", 
             "pct_no_vehicle", 
             "pct_nonwhite", 
             "pct_transit_commute", 
             "avg_weekday_exits"]

sns.heatmap(data = full_gdf[variables].corr(), annot=True)
# Out:
# <Axes: >

# %%
summary = full_gdf.groupby('station_type_y')[variables].mean()
summary
# Out:
#                 median_household_income  pct_no_vehicle  pct_nonwhite  \
# station_type_y
# core                      118551.897436       22.878718     69.278462
# peripheral                163149.550000        6.465000     66.989750
#
#                 pct_transit_commute  avg_weekday_exits
# station_type_y
# core                      15.542308            4258.35
# peripheral                 6.031500             851.90

# %%
COLORS = {"core": "#1B4F8A", "peripheral": "#D4763B"}
 
labels = {
    "median_household_income": "Median Household\nIncome ($)",
    "pct_no_vehicle":          "% No Vehicle",
    "pct_nonwhite":            "% Non-White",
    "pct_transit_commute":     "% Transit Commute",
    "avg_weekday_exits":       "Avg Weekday Exits",
}

variables = list(labels.keys())
x         = np.arange(len(variables))
width     = 0.35
 
fig, axes = plt.subplots(1, len(variables), figsize=(11, 5))
 
for ax, var in zip(axes, variables):
    for i, (group, color) in enumerate(COLORS.items()):
        val  = summary.loc[group, var]
        bar  = ax.bar(i, val, color=color, alpha=0.88,
                      edgecolor="white", linewidth=0.6, width=0.5)
 
        # Format value label based on variable type
        if "income" in var:
            fmt = f"${val:,.0f}"
        elif "exits" in var:
            fmt = f"{val:,.0f}"
        else:
            fmt = f"{val:.1f}%"
 
        ax.text(i, val + val * 0.02, fmt,
                ha="center", va="bottom", fontsize=8)
 
    ax.set_xticks([0, 1])
    ax.set_xticklabels(["Core", "Peripheral"], fontsize=9)
    ax.set_title(labels[var], fontsize=9, fontweight="bold", pad=8)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.set_ylim(0, max(summary[var]) * 1.2)   # consistent headroom for labels
 
# Shared legend
legend_patches = [
    plt.Rectangle((0, 0), 1, 1, color=COLORS["core"],       label="Core"),
    plt.Rectangle((0, 0), 1, 1, color=COLORS["peripheral"],  label="Peripheral"),
]
fig.legend(handles=legend_patches, loc="lower center",
           ncol=2, fontsize=9, framealpha=0.9,
           bbox_to_anchor=(0.5, -0.05))
 
fig.suptitle("Core vs Peripheral Stations",
             fontsize=12, fontweight="bold", y=1.02)
 
plt.tight_layout()
