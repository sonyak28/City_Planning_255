# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

from typing import Tuple, Optional
import time, re
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon, MultiPolygon
import overturemaps
from shapely import from_wkb
from palettable.colorbrewer.sequential import Oranges_9

from lonboard import Map, PolygonLayer, SolidPolygonLayer, viz
from lonboard.basemap import MaplibreBasemap, CartoStyle

from lonboard.colormap import apply_continuous_cmap, apply_categorical_cmap

# %%
df = gpd.read_file("../data/processed/census_tract_data_2024_clean.csv")
